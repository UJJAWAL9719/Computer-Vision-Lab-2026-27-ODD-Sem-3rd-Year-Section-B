# %% [markdown]
# NAME- UJJAWAL CHAUHAN SEC-'B' '62' CU24250259 LABSHEET -09  import  cv2 import  matplotlib.pyplot  as  plt from  ultralytics  import  YOLO  Creating new Ultralytics Settings v0.0.8 file  ✅   View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralyti Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=  model = YOLO ( "yolov8n.pt" )  Downloading  https://github.com/ultralytics/assets/releases/download/v8.4.0/yo  image = cv2.imread ( " /content/trafic.jpg " )  Choose Files   yolov8n.pt  yolov8n.pt (n/a) - 6549796 bytes, last modified: 9/16/2026 -  100% done  Saving yolov8n.pt to yolov8n (1).pt  from  google.colab  import  files uploaded = files.upload ( )  print (image.shape)  (427, 640, 3)  image = cv2.imread( "/content/trafic.jpg" )  plt.figure(figsize=( 10 ,  6 )) plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)) plt.axis( "off" ) plt.show()  9/16/26, 2:33 PM   Untitled0.ipynb - Colab  https://colab.research.google.com/drive/1pc_QajsALkKrFNgqPMdqmt20z4Mqo1oM#scrollTo=2CRf5yZabzpq&printMode=true   1 / 6

# %% [markdown]
# --- End of Page 1 ---

# %% [markdown]
# results = model(image)  0: 448x640 14 persons, 1 bicycle, 2 cars, 6 motorcycles, 3 traffic lights, 35 Speed: 28.0ms preprocess, 351.1ms inference, 29.5ms postprocess per image at   result_image = results[ 0 ].plot() plt.figure(figsize=( 10 ,  6 )) plt.imshow(cv2.cvtColor(result_image, cv2.COLOR_BG R2RGB)) plt.axis( "off" ) plt.show()  9/16/26, 2:33 PM   Untitled0.ipynb - Colab  https://colab.research.google.com/drive/1pc_QajsALkKrFNgqPMdqmt20z4Mqo1oM#scrollTo=2CRf5yZabzpq&printMode=true   2 / 6

# %% [markdown]
# --- End of Page 2 ---

# %% [markdown]
# for  result  in  results:      for  box  in  result.boxes:         class_id =  int (box.cls[ 0 ])         confidence =  float (box.conf[ 0 ])         class_name = model.names[class_id]          print (class_name,  round (confidence,  2 ))  person 0.88 car 0.82 motorcycle 0.81 traffic light 0.8 person 0.79 motorcycle 0.77 person 0.71 motorcycle 0.69 traffic light 0.69 car 0.69 bicycle 0.69 person 0.57 person 0.57 person 0.55 person 0.54 motorcycle 0.52 person 0.51 person 0.48 person 0.38 person 0.35 motorcycle 0.34 person 0.29 traffic light 0.29 motorcycle 0.28 person 0.28 person 0.27  9/16/26, 2:33 PM   Untitled0.ipynb - Colab  https://colab.research.google.com/drive/1pc_QajsALkKrFNgqPMdqmt20z4Mqo1oM#scrollTo=2CRf5yZabzpq&printMode=true   3 / 6

# %% [markdown]
# --- End of Page 3 ---

# %% [markdown]
# for  result  in  results:      for  box  in  result.boxes:         coordinates = box.xyxy[ 0 ].tolist()          print (coordinates)  [0.048778533935546875, 246.03140258789062, 51.627193450927734, 396.5487365722 [305.68817138671875, 248.94583129882812, 434.88140869140625, 316.858917236328 [587.7740478515625, 279.0653076171875, 639.5169677734375, 322.83935546875] [507.54498291015625, 154.95687866210938, 528.2782592773438, 204.160400390625] [67.11521911621094, 248.16522216796875, 153.2202911376953, 389.27288818359375 [444.96270751953125, 283.60760498046875, 510.75921630859375, 353.767761230468 [247.1812744140625, 250.3558349609375, 305.98809814453125, 355.22796630859375 [232.66018676757812, 284.68182373046875, 319.2168884277344, 374.599609375] [83.44184875488281, 148.12095642089844, 101.92953491210938, 199.0710296630859 [117.12605285644531, 259.31903076171875, 180.47496032714844, 299.056457519531 [69.0920639038086, 304.05718994140625, 209.47555541992188, 416.86505126953125 [207.9923095703125, 253.4197998046875, 230.34246826171875, 331.3564453125] [452.9288635253906, 254.8614501953125, 495.8410949707031, 336.0909423828125] [599.11279296875, 262.7510986328125, 631.7147216796875, 318.7728271484375] [426.04742431640625, 249.76043701171875, 447.54534912109375, 313.364318847656 [525.3120727539062, 276.247802734375, 574.2932739257812, 323.458984375] [224.19973754882812, 247.44650268554688, 260.72149658203125, 326.207122802734 [529.1549072265625, 257.9791259765625, 562.7249755859375, 313.7606201171875] [447.5753479003906, 252.4788818359375, 463.4424133300781, 285.4549560546875] [290.102294921875, 246.25216674804688, 309.7633056640625, 288.3544006347656] [498.2347412109375, 278.6514892578125, 535.740234375, 330.3831787109375] [277.93890380859375, 246.69732666015625, 302.98822021484375, 288.232971191406 [610.6944580078125, 194.94686889648438, 624.4278564453125, 222.8885498046875] [527.2647094726562, 284.03643798828125, 571.6786499023438, 320.00494384765625 [488.31268310546875, 257.115234375, 513.8153686523438, 284.7694091796875] [521.7244262695312, 257.38153076171875, 558.2191772460938, 314.02252197265625  count =  len (results[ 0 ].boxes) print ( "Total objects detected:" , count)  Total objects detected: 26  count =  len (results[ 0 ].boxes) print ( "Total objects detected:" , count)  Total objects detected: 26  detected_objects = [] for  result  in  results:      for  box  in  result.boxes:         class_id =  int (box.cls[ 0 ])         class_name = model.names[class_id]         detected_objects.append(class_name)  9/16/26, 2:33 PM   Untitled0.ipynb - Colab  https://colab.research.google.com/drive/1pc_QajsALkKrFNgqPMdqmt20z4Mqo1oM#scrollTo=2CRf5yZabzpq&printMode=true   4 / 6

# %% [markdown]
# --- End of Page 4 ---

# %% [markdown]
# print ( "Detected Objects:" ) print (detected_objects)  Detected Objects: ['person', 'car', 'motorcycle', 'traffic light', 'person', 'motorcycle', 'per  results = model(image, conf= 0.5 )  0: 448x640 8 persons, 1 bicycle, 2 cars, 4 motorcycles, 2 traffic lights, 308 Speed: 8.6ms preprocess, 308.1ms inference, 3.8ms postprocess per image at sh  result_image = results[ 0 ].plot() plt.figure(figsize=( 10 ,  6 )) plt.imshow(cv2.cvtColor(result_image, cv2.COLOR_BG R2RGB)) plt.axis( "off" ) plt.show()  for  result  in  results:      for  box  in  result.boxes:         class_id =  int ( box.cls [ 0 ] )         confidence =  float ( box.conf [ 0 ] )         class_name = model.names [ class_id ]          print ( "Object:" , class_name )          print ( "Confidence:" ,  round ( confidence,  2 ) )          print ( )  9/16/26, 2:33 PM   Untitled0.ipynb - Colab  https://colab.research.google.com/drive/1pc_QajsALkKrFNgqPMdqmt20z4Mqo1oM#scrollTo=2CRf5yZabzpq&printMode=true   5 / 6

# %% [markdown]
# --- End of Page 5 ---

# %% [markdown]
# Object: person Confidence: 0.88 Object: car Confidence: 0.82 Object: motorcycle Confidence: 0.81 Object: traffic light Confidence: 0.8 Object: person Confidence: 0.79 Object: motorcycle Confidence: 0.77 Object: person Confidence: 0.71 Object: motorcycle Confidence: 0.69 Object: traffic light Confidence: 0.69 Object: car Confidence: 0.69 Object: bicycle Confidence: 0.69 Object: person Confidence: 0.57  9/16/26, 2:33 PM   Untitled0.ipynb - Colab  https://colab.research.google.com/drive/1pc_QajsALkKrFNgqPMdqmt20z4Mqo1oM#scrollTo=2CRf5yZabzpq&printMode=true   6 / 6
